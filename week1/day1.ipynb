# %%
import os
from dotenv import load_dotenv
from scrapper import fetch_website_contents_farhan
from IPython.display import display, Markdown
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found")
elif not api_key.startswith("sk-proj-"):
    print("API key was found but it does not starts with sk-proj-")
elif api_key.strip() != api_key:
    print("API key was found but it looks like it have spaces or Tab")
else:
    print("API key is connected")
# Out:
# API key is connected

# %%
message= "Hello, GPT This is my first ever message to you! Hi!"

messages = [    {"role":"user","content":message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano",messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you. Welcome to our chat—I’m here to help with questions, explanations, writing, coding, planning, brainstorming, or just a friendly conversation.\n\nWhat would you like to do first? If you’re not sure, here are a few quick ideas:\n- Ask me a question and I’ll explain it.\n- Draft a message, email, or document.\n- Brainstorm ideas for a project or trip.\n- Practice a language or have a casual chat.\n- Solve a puzzle or explain a tricky concept.\n\nTell me what you’re curious about or what you’d like to work on.'

# %%
url = "https://edwarddonner.com"
ed = fetch_website_contents_farhan(url)
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 600,000 enrolled across 194 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# For more on me and my courses, please
# chat with me and my Digital Avatar here
# .
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook

# %%
system_prompt = """
You are a helpful assistant that analyzes the content of a website, and provides a short snarky, humorurs summary, 
ignoring text that might be naviagation related.
Respond in Markdown. Do not wrap markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt = """
Here is a contents of a website.
Provide a short summary of this website in a markdown.
If it includes news and announcements, then summarize these too.
"""

# %%
messages = [
    {"role": "system" ,"content":"You are a snarky assistant."},
    {"role": "user" ,"content":"What is 2+2?"}
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-nano",messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh, wow, a real brain-buster! It's 4. Sorry to break your math puzzle—hope you didn't need a calculator to figure that one out!

# %%
def messages_for(website): 
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt + website},
    ]

# %%
def summarizer(url):
    website = fetch_website_contents_farhan(url)
    response = openai.chat.completions.create(
        model="gpt-4.1-mini", 
        messages=messages_for(website=website)
        )
    return display(Markdown(response.choices[0].message.content))

# %%
summarizer("https://cnn.com/")
# Out:
# # CNN Website Summary
#
# CNN is basically your one-stop shop for all things newsy and dramatic—from world politics to the latest celebrity gossip, occasional weather tantrums, and even the looming World Cup 2026 soccer hype. They’ve got everything covered: US and global news, wars, elections, sports, fashion, and enough videos to keep you glued in a guilt-ridden binge-watch spiral.
#
# Oh, and if their ads annoy you or their videos refuse to load (because of course they sometimes do), there’s a handy little feedback form waiting to exact your revenge. Because nothing says "we care" like clicking through endless ad issues before you get to your doomscrolling.
#
# CNN: Where the news never sleeps, and neither do the loading wheels.
